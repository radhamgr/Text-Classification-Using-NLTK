# %% [markdown]
# # Build a Basic ML Model for Text Classification

# %%
#Load the dataset
import pandas as pd

dataset = pd.read_csv('final_dataset_basicmlmodel.csv')
dataset.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
for index, tweet in enumerate(dataset["tweet"][10:15]):
    print(index+1,".",tweet)
# Out:
# 1 .  â #ireland consumer price index (mom) climbed from previous 0.2% to 0.5% in may   #blog #silver #gold #forex
# 2 . we are so selfish. #orlando #standwithorlando #pulseshooting #orlandoshooting #biggerproblems #selfish #heabreaking   #values #love #
# 3 . i get to see my daddy today!!   #80days #gettingfed
# 4 . ouch...junior is angryð#got7 #junior #yugyoem   #omg
# 5 . i am thankful for having a paner. #thankful #positive

# %%
import re

def clean_text(text):
    #Filter to allow only alphabets
    text = re.sub(r'[^a-zA-Z\']',' ',text)
    
    #Remove Unicode characters
    text = re.sub(r'[^\x00-\x7F]+', '', text)
    
    #Convert to lowercase to maintain consistency
    text = text.lower()
       
    return text

# %%
dataset['clean_text'] = dataset.tweet.apply(lambda x: clean_text(x))

# %%
dataset.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                           clean_text  any_neg  is_question  \
# 0    user when a father is dysfunctional and is s...        0            1
# 1   user  user thanks for  lyft credit i can't us...        1            0
# 2                                bihday your majesty        0            0
# 3   model   i love u take with u all the time in ...        0            0
# 4             factsguide  society now     motivation        0            0
#
#    any_rare  char_count
# 0         1         102
# 1         1         122
# 2         0          21
# 3         0          86
# 4         0          39

# %%
STOPWORDS = ['a','about','above','after','again','against','ain','all','am','an','and','any','are','aren',"aren't",
 'as','at','be','because','been','before','being','below','between','both','but','by','can','couldn',"couldn't",
 'd',
 'did',
 'didn',
 "didn't",
 'do',
 'does',
 'doesn',
 "doesn't",
 'doing',
 'don',
 "don't",
 'down',
 'during',
 'each',
 'few',
 'for',
 'from',
 'further',
 'had',
 'hadn',
 "hadn't",
 'has',
 'hasn',
 "hasn't",
 'have',
 'haven',
 "haven't",
 'having',
 'he',
 'her',
 'here',
 'hers',
 'herself',
 'him',
 'himself',
 'his',
 'how',
 'i',
 'if',
 'in',
 'into',
 'is',
 'isn',
 "isn't",
 'it',
 "it's",
 'its',
 'itself',
 'just',
 'll',
 'm',
 'ma',
 'me',
 'mightn',
 "mightn't",
 'more',
 'most',
 'mustn',
 "mustn't",
 'my',
 'myself',
 'needn',
 "needn't",
 'no',
 'nor',
 'not',
 'now',
 'o',
 'of',
 'off',
 'on',
 'once',
 'only',
 'or',
 'other',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 're',
 's',
 'same',
 'shan',
 "shan't",
 'she',
 "she's",
 'should',
 "should've",
 'shouldn',
 "shouldn't",
 'so',
 'some',
 'such',
 't',
 'than',
 'that',
 "that'll",
 'the',
 'their',
 'theirs',
 'them',
 'themselves',
 'then',
 'there',
 'these',
 'they',
 'this',
 'those',
 'through',
 'to',
 'too',
 'under',
 'until',
 'up',
 've',
 'very',
 'was',
 'wasn',
 "wasn't",
 'we',
 'were',
 'weren',
 "weren't",
 'what',
 'when',
 'where',
 'which',
 'while',
 'who',
 'whom',
 'why',
 'will',
 'with',
 'won',
 "won't",
 'wouldn',
 "wouldn't",
 'y',
 'you',
 "you'd",
 "you'll",
 "you're",
 "you've",
 'your',
 'yours',
 'yourself',
 'yourselves']

# %%
def gen_freq(text):
    #Will store the list of words
    word_list = []
    
     #Loop over all the tweets and extract words into word_list
    for tw_words in text.split():
        word_list.extend(tw_words)
        
        #Create word frequencies using word_list
        word_freq = pd.Series(word_list).value_counts()
        
        #Drop the stopwords during the frequency calculation
        word_freq = word_freq.drop(STOPWORDS,errors = 'ignore')
        
        return word_freq

# %%
def any_neg(words):
    for word in words:
        if word in ['n', 'no', 'non', 'not'] or re.search(r"\wn't", word):
            return 1
    else:
        return 0

# %%
#Check whether one of the 100 rare words is present in the text
def any_rare(words, rare_100):
    for word in words:
        if word in rare_100:
            return 1
    else:
        return 0

# %%
#Check whether prompt words are present
def is_question(words):
    for word in words:
        if word in ['when', 'what', 'how', 'why', 'who']:
            return 1
    else:
        return 0

# %%
word_freq = gen_freq(dataset.clean_text.str)

#100 most rare words in the dataset
rare_100 = word_freq[-100:]

#Negation present or not
dataset['any_neg'] = dataset.clean_text.str.split().apply(lambda x: any_neg(x))

#Prompt present or not
dataset['is_question'] = dataset.clean_text.str.split().apply(lambda x: is_question(x))

#Any of the most 100 rare words present or not
dataset['any_rare'] = dataset.clean_text.str.split().apply(lambda x: any_rare(x, rare_100))

#Character count of the tweet
dataset['char_count'] = dataset.clean_text.apply(lambda x: len(x))

# %%
dataset.head()
# Out:
#          id  label                                              tweet  \
# 0         1      0   @user when a father is dysfunctional and is s...
# 1         2      0  @user @user thanks for #lyft credit i can't us...
# 2         3      0                                bihday your majesty
# 3         4      0  #model   i love u take with u all the time in ...
# 4         5      0             factsguide: society now    #motivation
# 5         6      0  [2/2] huge fan fare and big talking before the...
# 6         7      0   @user camping tomorrow @user @user @user @use...
# 7         8      0  the next school year is the year for exams.ð...
# 8         9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9        10      0   @user @user welcome here !  i'm   it's so #gr...
# 10       11      0   â #ireland consumer price index (mom) climb...
# 11       12      0  we are so selfish. #orlando #standwithorlando ...
# 12       13      0  i get to see my daddy today!!   #80days #getti...
# 13       16      0  ouch...junior is angryð#got7 #junior #yugyo...
# 14       17      0  i am thankful for having a paner. #thankful #p...
# 15       19      0  its #friday! ð smiles all around via ig use...
# 16       20      0  as we all know, essential oils are not made of...
# 17       21      0  #euro2016 people blaming ha for conceded goal ...
# 18       22      0  sad little dude..   #badday #coneofshame #cats...
# 19       23      0  product of the day: happy man #wine tool  who'...
# 20       25      0   @user #tgif   #ff to my #gamedev #indiedev #i...
# 21       26      0  beautiful sign by vendor 80 for $45.00!! #upsi...
# 22       27      0   @user all #smiles when #media is   !! ðð...
# 23       28      0  we had a great panel on the mediatization of t...
# 24       29      0        happy father's day @user ðððð
# 25       30      0  50 people went to nightclub to have a good nig...
# 26       31      0  i have never had a chance to vote for a presid...
# 27       32      0    #alohafriday #time does #not #exist #positiv...
# 28       33      0   @user rip to the fellow nohern ireland fan wh...
# 29       34      0  it was a hard monday due to cloudy weather. di...
# ...     ...    ...                                                ...
# 5212  31719      1   white girl has sex with black guy girls nackt...
# 5213  31720      1  are you #black &amp; feel like the  are stompi...
# 5214  31727      1  @user @user @user @user the real  and #antisem...
# 5215  31740      1  @user my video on the whole @user situation #b...
# 5216  31743      1  @user you might be a libtard if... #libtard  #...
# 5217  31758      1  @user stop these  chelski fans. #equality #div...
# 5218  31766      1  what has todayÂs attitude to women got in com...
# 5219  31773      1  #hatred,#greed&amp; destroyed many lives,but m...
# 5220  31778      1    bringing back morals #obama  #dividerofanation
# 5221  31790      1  #paladino is one of a rare breed of  that shou...
# 5222  31807      1  please don't forget to use the word ! that is ...
# 5223  31818      1  @user 'an unappetizing scam' :-) | women, we n...
# 5224  31830      1  that hammock just attempted #whitegenocide #li...
# 5225  31864      1  #us refuses to veto resolution on #israel  #zi...
# 5226  31865      1  @user #allahsoil we should not conflate islami...
# 5227  31866      1  see what #russia is doing in #syria,  destroyi...
# 5228  31883      1  come on n wake the eff up usa! this is crazine...
# 5229  31892      1  dr. frances cress welsing - racism defined #wh...
# 5230  31900      1  @user the end of   #me #selfie # #love #messi ...
# 5231  31904      1  @user @user  nothing. that would be .  #taharr...
# 5232  31913      1  i couldn't end #2016 without mentioning #trump...
# 5233  31927      1  a follow up from the gentlemen who were kicked...
# 5234  31930      1  did  keep #colinpowell and #condoleezzarice fr...
# 5235  31931      1  @user #feminismiscancer #feminismisterrorism #...
# 5236  31934      1  @user judd is a  &amp; #homophobic #freemilo #...
# 5237  31935      1  lady banned from kentucky mall. @user  #jcpenn...
# 5238  31947      1  @user omfg i'm offended! i'm a  mailbox and i'...
# 5239  31948      1  @user @user you don't have the balls to hashta...
# 5240  31949      1   makes you ask yourself, who am i? then am i a...
# 5241  31961      1  @user #sikh #temple vandalised in in #calgary,...
#
#                                              clean_text  any_neg  is_question  \
# 0       user when a father is dysfunctional and is s...        0            1
# 1      user  user thanks for  lyft credit i can't us...        1            0
# 2                                   bihday your majesty        0            0
# 3      model   i love u take with u all the time in ...        0            0
# 4                factsguide  society now     motivation        0            0
# 5           huge fan fare and big talking before the...        0            1
# 6       user camping tomorrow  user  user  user  use...        0            0
# 7     the next school year is the year for exams    ...        1            0
# 8     we won    love the land     allin  cavs  champ...        0            0
# 9       user  user welcome here    i'm   it's so  gr...        0            0
# 10          ireland consumer price index  mom  climb...        0            0
# 11    we are so selfish   orlando  standwithorlando ...        0            0
# 12    i get to see my daddy today        days  getti...        0            0
# 13    ouch   junior is angry     got   junior  yugyo...        0            0
# 14    i am thankful for having a paner   thankful  p...        0            0
# 15    its  friday       smiles all around via ig use...        0            0
# 16    as we all know  essential oils are not made of...        1            0
# 17     euro     people blaming ha for conceded goal ...        0            1
# 18    sad little dude      badday  coneofshame  cats...        0            0
# 19    product of the day  happy man  wine tool  who'...        0            0
# 20      user  tgif    ff to my  gamedev  indiedev  i...        0            0
# 21    beautiful sign by vendor    for           upsi...        0            0
# 22      user all  smiles when  media is             ...        0            1
# 23    we had a great panel on the mediatization of t...        0            0
# 24          happy father's day  user                           0            0
# 25       people went to nightclub to have a good nig...        0            0
# 26    i have never had a chance to vote for a presid...        1            0
# 27       alohafriday  time does  not  exist  positiv...        1            0
# 28      user rip to the fellow nohern ireland fan wh...        0            1
# 29    it was a hard monday due to cloudy weather  di...        0            0
# ...                                                 ...      ...          ...
# 5212   white girl has sex with black guy girls nackt...        0            0
# 5213  are you  black  amp  feel like the  are stompi...        0            0
# 5214   user  user  user  user the real  and  antisem...        1            0
# 5215   user my video on the whole  user situation  b...        0            0
# 5216   user you might be a libtard if     libtard   ...        0            0
# 5217   user stop these  chelski fans   equality  div...        0            0
# 5218  what has today  s attitude to women got in com...        0            1
# 5219   hatred  greed amp  destroyed many lives but m...        0            0
# 5220    bringing back morals  obama   dividerofanation         0            0
# 5221   paladino is one of a rare breed of  that shou...        0            0
# 5222  please don't forget to use the word   that is ...        1            1
# 5223   user 'an unappetizing scam'       women  we n...        0            0
# 5224  that hammock just attempted  whitegenocide  li...        0            0
# 5225   us refuses to veto resolution on  israel   zi...        0            0
# 5226   user  allahsoil we should not conflate islami...        1            0
# 5227  see what  russia is doing in  syria   destroyi...        0            1
# 5228  come on n wake the eff up usa  this is crazine...        1            0
# 5229  dr  frances cress welsing   racism defined  wh...        0            0
# 5230   user the end of    me  selfie    love  messi ...        0            0
# 5231   user  user  nothing  that would be     taharr...        0            0
# 5232  i couldn't end       without mentioning  trump...        1            0
# 5233  a follow up from the gentlemen who were kicked...        0            1
# 5234  did  keep  colinpowell and  condoleezzarice fr...        1            0
# 5235   user  feminismiscancer  feminismisterrorism  ...        0            1
# 5236   user judd is a   amp   homophobic  freemilo  ...        0            0
# 5237  lady banned from kentucky mall   user   jcpenn...        0            0
# 5238   user omfg i'm offended  i'm a  mailbox and i'...        0            0
# 5239   user  user you don't have the balls to hashta...        1            0
# 5240   makes you ask yourself  who am i  then am i a...        0            1
# 5241   user  sikh  temple vandalised in in  calgary ...        0            0
#
#       any_rare  char_count
# 0            1         102
# 1            1         122
# 2            0          21
# 3            0          86
# 4            0          39
# 5            0         116
# 6            1          74
# 7            0         143
# 8            0          87
# 9            1          50
# 10           0         111
# 11           1         133
# 12           0          51
# 13           0          56
# 14           0          58
# 15           1          78
# 16           0          58
# 17           0         127
# 18           0          70
# 19           0         100
# 20           1          95
# 21           0          79
# 22           1         127
# 23           0          72
# 24           1          43
# 25           0         135
# 26           0         125
# 27           1          87
# 28           1         122
# 29           0         106
# ...        ...         ...
# 5212         0          64
# 5213         0          88
# 5214         1         108
# 5215         1         111
# 5216         1          69
# 5217         1          53
# 5218         0         107
# 5219         0         135
# 5220         0          47
# 5221         0         109
# 5222         0         108
# 5223         1         108
# 5224         0          87
# 5225         0          73
# 5226         1          97
# 5227         0          58
# 5228         0         111
# 5229         0          83
# 5230         1          87
# 5231         1          76
# 5232         0          86
# 5233         1          99
# 5234         0         117
# 5235         1          97
# 5236         1         108
# 5237         1          59
# 5238         1          82
# 5239         1         112
# 5240         0          87
# 5241         1          67
#
# [5242 rows x 8 columns]

# %%
#Top 10 common words are
gen_freq(dataset.clean_text.str)[:10]
# Out:
# dysfunctional    1
# drags            1
# run              1
# user             1
# selfish          1
# father           1
# dysfunction      1
# kids             1
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = dataset[['any_neg', 'any_rare', 'char_count', 'is_question']]
y = dataset.label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=27)

# %%
from sklearn.naive_bayes import GaussianNB

#Initialize GaussianNB classifier
model = GaussianNB()
#Fit the model on the train dataset
model = model.fit(X_train, y_train)
#Make predictions on the test dataset
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, pred)*100, "%")
# Out:
# Accuracy: 59.238095238095234 %
